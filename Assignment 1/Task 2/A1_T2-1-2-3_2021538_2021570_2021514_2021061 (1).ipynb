# %%
import numpy as np
import numpy as np
from transformers import pipeline
from tqdm import tqdm

classifier = pipeline("text-classification",model='bhadresh-savani/distilbert-base-uncased-emotion', return_all_scores=True,)

def emotion_scores(sample): 
    emotion=classifier(sample)
    return emotion[0]
# Out:
# Downloading config.json:   0%|          | 0.00/768 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /home/manav/anaconda3/lib/python3.11/site-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
import random
import numpy as np

# %%
class BigramLM:
    def __init__(self, vocab):
        self.vocab = vocab
        self.vocab_size = len(vocab)
        self.word_idx = {}
        for i in range(self.vocab_size):
            self.word_idx[self.vocab[i]] = i
        self.bigram_counts = np.zeros((self.vocab_size, self.vocab_size))
        self.unigram_counts = np.zeros(self.vocab_size)
        self.unigram_prob = np.zeros(self.vocab_size)
        self.bigram_prob = np.zeros((self.vocab_size, self.vocab_size))
        self.emotion_matrix = np.zeros((6,self.vocab_size,self.vocab_size))
        self.unigram_emotions = np.zeros((6,self.vocab_size))
        self.emotions = ['sadness', 'joy', 'love', 'anger', 'fear', 'surprise']
        self.stop_words = []

    def calc_emotion(self):
        for i in tqdm(range(self.vocab_size)):
            scores = emotion_scores(self.vocab[i])
            for j in range(6):
                self.unigram_emotions[j][i] = scores[j]['score']

    def learn_from_dataset(self, dataset):
        for sentence in dataset:
            for word in sentence:
                word_idx = self.word_idx[word]
                self.unigram_counts[word_idx] += 1

            for i in range(1, len(sentence)):
                prev_word_idx = self.word_idx[sentence[i-1]]
                curr_word_idx = self.word_idx[sentence[i]]
                
                self.bigram_counts[prev_word_idx, curr_word_idx] += 1

        self.unigram_prob = self.unigram_counts/np.sum(self.unigram_counts)
        self.calc_emotion()

        #generating list of stop words
        for i in dataset:
            self.stop_words.append(i[-1])
        freq_word = {}
        for word in self.stop_words:
            if word not in freq_word:
                freq_word[word] = 1
            else:
                freq_word[word] += 1

        
        sorted_dict = sorted(freq_word.items(), key=lambda item: item[1], reverse=True)[:100]
        top_words = [item[0] for item in sorted_dict]
        self.stop_words = top_words

        for i in range(len(self.bigram_counts)):
            self.bigram_prob[i] = self.bigram_counts[i] / self.unigram_counts[i]
        
        for i in range(6):
            for j in tqdm(range(self.vocab_size)):
                for k in range(self.vocab_size):
                    self.emotion_matrix[i][j][k] = self.bigram_prob[j][k] + self.unigram_emotions[i][k]
                self.emotion_matrix[i][j] /= np.sum(self.emotion_matrix[i][j])

        return self.emotion_matrix
    
    def laplace_smoothing(self,debug=False):
        smoothed_probabilities = np.zeros((self.vocab_size, self.vocab_size))

        for i in range(len(self.bigram_counts)):
            smoothed_probabilities[i] = (self.bigram_counts[i] + 1) / (self.unigram_counts[i] + self.vocab_size)

        if(debug):
            print(smoothed_probabilities)
        return smoothed_probabilities

    def kneser_ney_smoothing(self, discount=0.75, debug=True):
    
        # Initialize the KN smoothed probability matrix
        kneser_ney_prob = np.zeros((self.vocab_size, self.vocab_size))

        # Calculate total number of bigrams
        total_bigrams = np.sum(self.bigram_counts > 0)

        # Calculate continuation probabilities
        continuation_prob = np.zeros(self.vocab_size)
        for word_idx in range(self.vocab_size):
            continuation_prob[word_idx] = len(np.where(self.bigram_counts[:, word_idx] > 0)[0]) / total_bigrams

        # Calculate lambda for each word
        lambda_ = np.zeros(self.vocab_size)

        for prev_word_idx in range(self.vocab_size):
            # The number of word types that can follow w_(i-1)
            continuation_types = len(np.where(self.bigram_counts[prev_word_idx, :] > 0)[0])
            bigram_count_sum = np.sum(self.bigram_counts[prev_word_idx, :])
            if bigram_count_sum > 0:
                lambda_[prev_word_idx] = (discount * continuation_types) / bigram_count_sum
            else:
                lambda_[prev_word_idx] = 0  # Avoid division by zero if there are no following words

        # Calculate adjusted probabilities for each bigram
        for i in range(self.vocab_size):
            for j in range(self.vocab_size):
                if self.unigram_counts[i] > 0:
                    # Apply the discount and divide by the unigram count
                    kneser_ney_prob[i, j] = max(self.bigram_counts[i, j] - discount, 0) / self.unigram_counts[i]
                    
                    # Add the lambda times the continuation probability for the next word
                    kneser_ney_prob[i, j] += lambda_[i] * continuation_prob[j]

        # Update the class property with the new probabilities
        self.bigram_prob = kneser_ney_prob

        return kneser_ney_prob  
    
    
    def generate_next_word(self, current_word, emotion,k = 4):
        if current_word not in self.vocab:
            raise ValueError("Word not in vocabulary")
        
        if emotion not in self.emotions:
            raise ValueError("Invalid emotion")
        
        current_word_idx = self.word_idx[current_word]
        emotion_idx = self.emotions.index(emotion)
        next_word_probs = self.emotion_matrix[emotion_idx][current_word_idx]

        sorted_indices = np.argsort(next_word_probs)
        topk = sorted_indices[-k:]
        next_word_idx = np.random.choice(topk)
        return self.vocab[next_word_idx]
    
    def generate_sentence(self, initial_word, emotion, length = 6, k=4):
        sentence = [initial_word]
        while(length):
            next = self.generate_next_word(sentence[-1],emotion=emotion,k=k)
            sentence.append(next)
            if next in self.stop_words and len(sentence)>2:
                break
            length-=1
        return ' '.join(sentence)

file_path = 'corpus.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    dataset = []
    for line in file:
        dataset.append(line.lower().split())

flat_dataset = [word for sentence in dataset for word in sentence]

vocab = []

for sentence in dataset:
    for word in sentence:
        if word not in vocab:
            vocab.append(word)

bigram_model = BigramLM(vocab)
bigram_model.learn_from_dataset(dataset)
# Out:
# 100%|██████████| 5429/5429 [01:32<00:00, 58.73it/s]
# 100%|██████████| 5429/5429 [00:15<00:00, 352.20it/s]
# 100%|██████████| 5429/5429 [00:15<00:00, 350.95it/s]
# 100%|██████████| 5429/5429 [00:15<00:00, 353.32it/s]
# 100%|██████████| 5429/5429 [00:14<00:00, 365.17it/s]
# 100%|██████████| 5429/5429 [00:15<00:00, 356.31it/s]
# 100%|██████████| 5429/5429 [00:15<00:00, 349.61it/s]
# array([[[9.01217817e-05, 4.77863333e-05, 1.10238852e-04, ...,
#          1.06249687e-04, 7.52789725e-05, 9.02315019e-05],
#         [8.95600024e-05, 4.66631467e-05, 3.23000841e-04, ...,
#          1.06249388e-04, 7.52787612e-05, 9.02312486e-05],
#         [4.34679927e-04, 4.66738823e-05, 1.10263905e-04, ...,
#          1.06273833e-04, 7.52960803e-05, 9.02520077e-05],
#         ...,
#         [8.95600024e-05, 4.66631467e-05, 1.10238543e-04, ...,
#          6.30622603e-05, 8.40056012e-05, 4.30748164e-04],
#         [2.26691802e-04, 3.56747100e-05, 1.78154159e-04, ...,
#          6.30690077e-05, 8.40145894e-05, 4.30794252e-04],
#         ...,
#         [6.61920471e-05, 3.56708934e-05, 1.78135099e-04, ...,
#          6.30622603e-05, 8.40056012e-05, 4.30748164e-04],
#         [6.61920471e-05, 3.56708934e-05, 1.78135099e-04, ...,
#          6.30622603e-05, 8.40056012e-05, 4.30748164e-04],
#         [6.61920471e-05, 3.56708934e-05, 1.78135099e-04, ...,
#          6.30622603e-05, 8.40056012e-05, 4.30748164e-04]],
#
#        [[4.65777257e-05, 4.90418972e-05, 3.07183280e-04, ...,
#          4.36133952e-05, 6.92982866e-05, 1.06240997e-04],
#         [4.29328730e-05, 4.17529957e-05, 1.68789080e-03, ...,
#          4.36126006e-05, 6.92970240e-05, 1.06239061e-04],
#         [2.28533835e-03, 4.18154120e-05, 3.07636881e-04, ...,
#          4.36777968e-05, 6.94006157e-05, 1.06397877e-04],
#         ...,
#         [4.29328730e-05, 4.17529957e-05, 3.07177683e-04, ...,
#          4.36126006e-05, 6.92970240e-05, 1.06239061e-04],
#         [4.29328730e-05, 4.17529957e-05, 3.07177683e-04, ...,
#          4.36126006e-05, 6.92970240e-05, 1.06239061e-04],
#         [4.29328730e-05, 4.17529957e-05, 3.07177683e-04, ...,
#          4.36126006e-05, 6.92970240e-05, 1.06239061e-04]]])

# %%
k = bigram_model.kneser_ney_smoothing(debug=True)
print(np.sum(k[0]))
l = bigram_model.laplace_smoothing(debug=False)
print(np.sum(l[0]))
# Out:
# 0.9987954728191153
# 0.9994575829898025

# %%
start_words = set()
for i in dataset:
    start_words.add(i[0])
start_words = list(start_words)
print(len(start_words))
# Out:
# 16

# %%
bigram_model.generate_sentence('i','surprise',length=10, k=10)
# Out:
# 'i amazing surprising amount surprised amazing'

# %%
import random
emotions = ['sadness', 'joy', 'love', 'anger', 'fear', 'surprise']
file = open('gen.txt', 'w')
label = open('gen_labels.txt', 'w')
for emotion in emotions:
    emotion_file = open(f"gen_{emotion}.txt", "w")
    for i in range(50):
        startword = random.choice(start_words)
        x = bigram_model.generate_sentence(startword, emotion, 10, 108)
        print(emotion_scores(x))
        file.write(x+'\n')
        emotion_file.write(x+'\n')
        label.write(emotion+'\n')
    emotion_file.close()
label.close()
file.close()
# Out:
# [{'label': 'sadness', 'score': 0.9988045692443848}, {'label': 'joy', 'score': 0.0003073704428970814}, {'label': 'love', 'score': 0.0001781464961823076}, {'label': 'anger', 'score': 0.00032467665732838213}, {'label': 'fear', 'score': 0.00022172930766828358}, {'label': 'surprise', 'score': 0.00016358279390260577}]
# [{'label': 'sadness', 'score': 0.2093583345413208}, {'label': 'joy', 'score': 0.0024985293857753277}, {'label': 'love', 'score': 0.0030538619030267}, {'label': 'anger', 'score': 0.7817633152008057}, {'label': 'fear', 'score': 0.00277901953086257}, {'label': 'surprise', 'score': 0.0005469870520755649}]
# [{'label': 'sadness', 'score': 0.9976517558097839}, {'label': 'joy', 'score': 0.0004407524538692087}, {'label': 'love', 'score': 0.0006268264260143042}, {'label': 'anger', 'score': 0.00039638395537622273}, {'label': 'fear', 'score': 0.000706476450432092}, {'label': 'surprise', 'score': 0.00017779548943508416}]
# [{'label': 'sadness', 'score': 0.9986181259155273}, {'label': 'joy', 'score': 0.00033643163624219596}, {'label': 'love', 'score': 0.00021132780238986015}, {'label': 'anger', 'score': 0.00040954991709440947}, {'label': 'fear', 'score': 0.0002368707791902125}, {'label': 'surprise', 'score': 0.0001877279137261212}]
# [{'label': 'sadness', 'score': 0.9982642531394958}, {'label': 'joy', 'score': 0.0002761062642093748}, {'label': 'love', 'score': 0.0002956912503577769}, {'label': 'anger', 'score': 0.0002626523782964796}, {'label': 'fear', 'score': 0.0007520852377638221}, {'label': 'surprise', 'score': 0.00014924818242434412}]
# [{'label': 'sadness', 'score': 0.9969416260719299}, {'label': 'joy', 'score': 0.0005085751763544977}, {'label': 'love', 'score': 0.00047661474673077464}, {'label': 'anger', 'score': 0.0016895864391699433}, {'label': 'fear', 'score': 0.00024642088101245463}, {'label': 'surprise', 'score': 0.0001372702099615708}]
# [{'label': 'sadness', 'score': 0.9986957907676697}, {'label': 'joy', 'score': 0.00038560840766876936}, {'label': 'love', 'score': 0.00026783329667523503}, {'label': 'anger', 'score': 0.00030650972621515393}, {'label': 'fear', 'score': 0.0002069365291390568}, {'label': 'surprise', 'score': 0.00013727732584811747}]
# [{'label': 'sadness', 'score': 0.9972102046012878}, {'label': 'joy', 'score': 0.0004743885656353086}, {'label': 'love', 'score': 0.00035844225203618407}, {'label': 'anger', 'score': 0.0007928808336146176}, {'label': 'fear', 'score': 0.0010511475848034024}, {'label': 'surprise', 'score': 0.00011291725968476385}]
# [{'label': 'sadness', 'score': 0.997907280921936}, {'label': 'joy', 'score': 0.0006128174718469381}, {'label': 'love', 'score': 0.000625526939984411}, {'label': 'anger', 'score': 0.0004238016263116151}, {'label': 'fear', 'score': 0.00031670776661485434}, {'label': 'surprise', 'score': 0.00011400392395444214}]
# [{'label': 'sadness', 'score': 0.9988588094711304}, {'label': 'joy', 'score': 0.00033480444108136}, {'label': 'love', 'score': 0.00023381589562632143}, {'label': 'anger', 'score': 0.00028658981318585575}, {'label': 'fear', 'score': 0.0001688776828814298}, {'label': 'surprise', 'score': 0.0001170876421383582}]
# [{'label': 'sadness', 'score': 0.9974697828292847}, {'label': 'joy', 'score': 0.000756232300773263}, {'label': 'love', 'score': 0.0002600081788841635}, {'label': 'anger', 'score': 0.0011224498739466071}, {'label': 'fear', 'score': 0.00021867254690732807}, {'label': 'surprise', 'score': 0.00017279245366808027}]
# [{'label': 'sadness', 'score': 0.9988275170326233}, {'label': 'joy', 'score': 0.0003517619625199586}, {'label': 'love', 'score': 0.0002521187416277826}, {'label': 'anger', 'score': 0.000290552998194471}, {'label': 'fear', 'score': 0.00014544639270752668}, {'label': 'surprise', 'score': 0.00013261623098514974}]
# [{'label': 'sadness', 'score': 0.9989272952079773}, {'label': 'joy', 'score': 0.00028378679417073727}, {'label': 'love', 'score': 0.00024016005045268685}, {'label': 'anger', 'score': 0.00024259177735075355}, {'label': 'fear', 'score': 0.00019712003995664418}, {'label': 'surprise', 'score': 0.00010904248483711854}]
# [{'label': 'sadness', 'score': 0.9988011121749878}, {'label': 'joy', 'score': 0.0002765051322057843}, {'label': 'love', 'score': 0.00018228110275231302}, {'label': 'anger', 'score': 0.00042775156907737255}, {'label': 'fear', 'score': 0.0001941262453328818}, {'label': 'surprise', 'score': 0.00011828025890281424}]
# [{'label': 'sadness', 'score': 0.9984683394432068}, {'label': 'joy', 'score': 0.0004668224137276411}, {'label': 'love', 'score': 0.00032473428291268647}, {'label': 'anger', 'score': 0.0004776248533744365}, {'label': 'fear', 'score': 0.000143412544275634}, {'label': 'surprise', 'score': 0.00011906986037502065}]
# [{'label': 'sadness', 'score': 0.9986913800239563}, {'label': 'joy', 'score': 0.0003099203750025481}, {'label': 'love', 'score': 0.0002272613055538386}, {'label': 'anger', 'score': 0.0004487774276640266}, {'label': 'fear', 'score': 0.00016798543219920248}, {'label': 'surprise', 'score': 0.00015459716087207198}]
# [{'label': 'sadness', 'score': 0.6878452301025391}, {'label': 'joy', 'score': 0.00260667921975255}, {'label': 'love', 'score': 0.006748472806066275}, {'label': 'anger', 'score': 0.2989712953567505}, {'label': 'fear', 'score': 0.0029468752909451723}, {'label': 'surprise', 'score': 0.0008814104367047548}]
# [{'label': 'sadness', 'score': 0.9981541037559509}, {'label': 'joy', 'score': 0.0006117907469160855}, {'label': 'love', 'score': 0.00022068925318308175}, {'label': 'anger', 'score': 0.0005424791597761214}, {'label': 'fear', 'score': 0.00034595566103234887}, {'label': 'surprise', 'score': 0.00012493308167904615}]
# [{'label': 'sadness', 'score': 0.998694121837616}, {'label': 'joy', 'score': 0.0003820414422079921}, {'label': 'love', 'score': 0.00025484917568974197}, {'label': 'anger', 'score': 0.0003819926059804857}, {'label': 'fear', 'score': 0.00017244549235329032}, {'label': 'surprise', 'score': 0.00011455477942945436}]
# [{'label': 'sadness', 'score': 0.1868552565574646}, {'label': 'joy', 'score': 0.002368038520216942}, {'label': 'love', 'score': 0.004496231209486723}, {'label': 'anger', 'score': 0.804114818572998}, {'label': 'fear', 'score': 0.0014978043036535382}, {'label': 'surprise', 'score': 0.000667883432470262}]
# [{'label': 'sadness', 'score': 0.9988760352134705}, {'label': 'joy', 'score': 0.0003089288657065481}, {'label': 'love', 'score': 0.0001997613871935755}, {'label': 'anger', 'score': 0.00025527970865368843}, {'label': 'fear', 'score': 0.00021248735720291734}, {'label': 'surprise', 'score': 0.0001475737662985921}]
# [{'label': 'sadness', 'score': 0.9982078075408936}, {'label': 'joy', 'score': 0.000625420652795583}, {'label': 'love', 'score': 0.0002206209464929998}, {'label': 'anger', 'score': 0.00043729221215471625}, {'label': 'fear', 'score': 0.0003807759203482419}, {'label': 'surprise', 'score': 0.00012804106518160552}]
# [{'label': 'sadness', 'score': 0.9988411068916321}, {'label': 'joy', 'score': 0.0003309535386506468}, {'label': 'love', 'score': 0.0002528464829083532}, {'label': 'anger', 'score': 0.0002714168222155422}, {'label': 'fear', 'score': 0.00017741801275406033}, {'label': 'surprise', 'score': 0.00012642437650356442}]
# [{'label': 'sadness', 'score': 0.9987084865570068}, {'label': 'joy', 'score': 0.0003067803627345711}, {'label': 'love', 'score': 0.00023747807426843792}, {'label': 'anger', 'score': 0.00042204957571811974}, {'label': 'fear', 'score': 0.00019288720795884728}, {'label': 'surprise', 'score': 0.0001322943571722135}]
# [{'label': 'sadness', 'score': 0.9989412426948547}, {'label': 'joy', 'score': 0.0002679083263501525}, {'label': 'love', 'score': 0.00015255206380970776}, {'label': 'anger', 'score': 0.00033871823688969016}, {'label': 'fear', 'score': 0.00017974870570469648}, {'label': 'surprise', 'score': 0.00011993513180641457}]
# [{'label': 'sadness', 'score': 0.9988585710525513}, {'label': 'joy', 'score': 0.0002972843067254871}, {'label': 'love', 'score': 0.00022810869268141687}, {'label': 'anger', 'score': 0.0002760807692538947}, {'label': 'fear', 'score': 0.0001802262559067458}, {'label': 'surprise', 'score': 0.00015955304843373597}]
# [{'label': 'sadness', 'score': 0.9955535531044006}, {'label': 'joy', 'score': 0.0003246322157792747}, {'label': 'love', 'score': 0.0003378209366928786}, {'label': 'anger', 'score': 0.0012200702913105488}, {'label': 'fear', 'score': 0.002342245541512966}, {'label': 'surprise', 'score': 0.0002217089058831334}]
# [{'label': 'sadness', 'score': 0.996081531047821}, {'label': 'joy', 'score': 0.0006453693495132029}, {'label': 'love', 'score': 0.00040653374162502587}, {'label': 'anger', 'score': 0.002275468548759818}, {'label': 'fear', 'score': 0.00032537453807890415}, {'label': 'surprise', 'score': 0.0002657892182469368}]
# [{'label': 'sadness', 'score': 0.9942823648452759}, {'label': 'joy', 'score': 0.0013296524994075298}, {'label': 'love', 'score': 0.0008445392595604062}, {'label': 'anger', 'score': 0.002598462626338005}, {'label': 'fear', 'score': 0.0007151929312385619}, {'label': 'surprise', 'score': 0.00022985412215348333}]
# [{'label': 'sadness', 'score': 0.9987062215805054}, {'label': 'joy', 'score': 0.0002789023274090141}, {'label': 'love', 'score': 0.00021607241069432348}, {'label': 'anger', 'score': 0.00047727892524562776}, {'label': 'fear', 'score': 0.00022600071679335088}, {'label': 'surprise', 'score': 9.550544928060845e-05}]
# [{'label': 'sadness', 'score': 0.9988256096839905}, {'label': 'joy', 'score': 0.00034869182854890823}, {'label': 'love', 'score': 0.0001991542085306719}, {'label': 'anger', 'score': 0.0003571215202100575}, {'label': 'fear', 'score': 0.00013477068569045514}, {'label': 'surprise', 'score': 0.00013466467498801649}]
# [{'label': 'sadness', 'score': 0.9989946484565735}, {'label': 'joy', 'score': 0.00018616353918332607}, {'label': 'love', 'score': 0.0002247639058623463}, {'label': 'anger', 'score': 0.000267157971393317}, {'label': 'fear', 'score': 0.00022371731756720692}, {'label': 'surprise', 'score': 0.00010358577128499746}]
# [{'label': 'sadness', 'score': 0.9983221888542175}, {'label': 'joy', 'score': 0.0003331509360577911}, {'label': 'love', 'score': 0.0002477697271388024}, {'label': 'anger', 'score': 0.0006356363301165402}, {'label': 'fear', 'score': 0.0003365647280588746}, {'label': 'surprise', 'score': 0.00012476871779654175}]
# [{'label': 'sadness', 'score': 0.0010597450891509652}, {'label': 'joy', 'score': 0.0012196649331599474}, {'label': 'love', 'score': 0.995559811592102}, {'label': 'anger', 'score': 0.00070814328501001}, {'label': 'fear', 'score': 0.0005565846804529428}, {'label': 'surprise', 'score': 0.0008959986153058708}]
# [{'label': 'sadness', 'score': 0.0008145367028191686}, {'label': 'joy', 'score': 0.044824130833148956}, {'label': 'love', 'score': 0.9529786705970764}, {'label': 'anger', 'score': 0.0005684454808942974}, {'label': 'fear', 'score': 0.00028256644145585597}, {'label': 'surprise', 'score': 0.0005316932802088559}]
# [{'label': 'sadness', 'score': 0.0013391600223258138}, {'label': 'joy', 'score': 0.0013975522015243769}, {'label': 'love', 'score': 0.9949814677238464}, {'label': 'anger', 'score': 0.0007296240655705333}, {'label': 'fear', 'score': 0.0007769337389618158}, {'label': 'surprise', 'score': 0.0007753435056656599}]
# [{'label': 'sadness', 'score': 0.0007615463109686971}, {'label': 'joy', 'score': 0.0039273714646697044}, {'label': 'love', 'score': 0.9939221143722534}, {'label': 'anger', 'score': 0.00029518076917156577}, {'label': 'fear', 'score': 0.0005024259444326162}, {'label': 'surprise', 'score': 0.0005915244692005217}]
# [{'label': 'sadness', 'score': 0.0012656442122533917}, {'label': 'joy', 'score': 0.002359001664444804}, {'label': 'love', 'score': 0.9917922019958496}, {'label': 'anger', 'score': 0.0031800998840481043}, {'label': 'fear', 'score': 0.0006062807515263557}, {'label': 'surprise', 'score': 0.0007968745194375515}]
# [{'label': 'sadness', 'score': 0.0009325590217486024}, {'label': 'joy', 'score': 0.0038557182997465134}, {'label': 'love', 'score': 0.993442177772522}, {'label': 'anger', 'score': 0.0007196881924755871}, {'label': 'fear', 'score': 0.00044737179996445775}, {'label': 'surprise', 'score': 0.0006024890462867916}]
# [{'label': 'sadness', 'score': 0.0005457423394545913}, {'label': 'joy', 'score': 0.00047386978985741735}, {'label': 'love', 'score': 0.0002600879524834454}, {'label': 'anger', 'score': 0.9972297549247742}, {'label': 'fear', 'score': 0.0013105468824505806}, {'label': 'surprise', 'score': 0.00017992706852965057}]
# [{'label': 'sadness', 'score': 0.000535621598828584}, {'label': 'joy', 'score': 0.000308930961182341}, {'label': 'love', 'score': 0.0003019490104634315}, {'label': 'anger', 'score': 0.9980744123458862}, {'label': 'fear', 'score': 0.000615274126175791}, {'label': 'surprise', 'score': 0.00016381745808757842}]
# [{'label': 'sadness', 'score': 0.0004499628848861903}, {'label': 'joy', 'score': 0.00034177940688095987}, {'label': 'love', 'score': 0.0002653569099493325}, {'label': 'anger', 'score': 0.9980841875076294}, {'label': 'fear', 'score': 0.0006605273811146617}, {'label': 'surprise', 'score': 0.00019810257072094828}]
# ...
# [{'label': 'sadness', 'score': 0.0015985282370820642}, {'label': 'joy', 'score': 0.003000325057655573}, {'label': 'love', 'score': 0.0016874116845428944}, {'label': 'anger', 'score': 0.33281323313713074}, {'label': 'fear', 'score': 0.6592398881912231}, {'label': 'surprise', 'score': 0.0016606567660346627}]
# [{'label': 'sadness', 'score': 0.006110639777034521}, {'label': 'joy', 'score': 0.012355227023363113}, {'label': 'love', 'score': 0.0011717126471921802}, {'label': 'anger', 'score': 0.005212503019720316}, {'label': 'fear', 'score': 0.468425452709198}, {'label': 'surprise', 'score': 0.50672447681427}]
# [{'label': 'sadness', 'score': 0.0012366625014692545}, {'label': 'joy', 'score': 0.003967182245105505}, {'label': 'love', 'score': 0.0009893107926473022}, {'label': 'anger', 'score': 0.0011076531372964382}, {'label': 'fear', 'score': 0.0038200097624212503}, {'label': 'surprise', 'score': 0.9888792037963867}]
# [{'label': 'sadness', 'score': 0.006931639276444912}, {'label': 'joy', 'score': 0.5730338096618652}, {'label': 'love', 'score': 0.003127584233880043}, {'label': 'anger', 'score': 0.007212151773273945}, {'label': 'fear', 'score': 0.020722392946481705}, {'label': 'surprise', 'score': 0.3889724016189575}]
# [{'label': 'sadness', 'score': 0.022571789100766182}, {'label': 'joy', 'score': 0.034923672676086426}, {'label': 'love', 'score': 0.5146193504333496}, {'label': 'anger', 'score': 0.022656256332993507}, {'label': 'fear', 'score': 0.22226902842521667}, {'label': 'surprise', 'score': 0.18295986950397491}]
# [{'label': 'sadness', 'score': 0.021531779319047928}, {'label': 'joy', 'score': 0.5845928192138672}, {'label': 'love', 'score': 0.05770181864500046}, {'label': 'anger', 'score': 0.012013525702059269}, {'label': 'fear', 'score': 0.06406410783529282}, {'label': 'surprise', 'score': 0.26009589433670044}]
# [{'label': 'sadness', 'score': 0.0010115421609953046}, {'label': 'joy', 'score': 0.0034803699236363173}, {'label': 'love', 'score': 0.0009578792960382998}, {'label': 'anger', 'score': 0.0007579443627037108}, {'label': 'fear', 'score': 0.004690888337790966}, {'label': 'surprise', 'score': 0.9891013503074646}]
# [{'label': 'sadness', 'score': 0.0009935555281117558}, {'label': 'joy', 'score': 0.002488922793418169}, {'label': 'love', 'score': 0.000681307225022465}, {'label': 'anger', 'score': 0.0007948863785713911}, {'label': 'fear', 'score': 0.010893957689404488}, {'label': 'surprise', 'score': 0.984147310256958}]
# [{'label': 'sadness', 'score': 0.005841181147843599}, {'label': 'joy', 'score': 0.14536800980567932}, {'label': 'love', 'score': 0.002251152414828539}, {'label': 'anger', 'score': 0.0069389864802360535}, {'label': 'fear', 'score': 0.012833991087973118}, {'label': 'surprise', 'score': 0.8267666697502136}]
# [{'label': 'sadness', 'score': 0.16377916932106018}, {'label': 'joy', 'score': 0.6197322607040405}, {'label': 'love', 'score': 0.03715488687157631}, {'label': 'anger', 'score': 0.005446188151836395}, {'label': 'fear', 'score': 0.09870090335607529}, {'label': 'surprise', 'score': 0.07518661022186279}]
# [{'label': 'sadness', 'score': 0.004129990469664335}, {'label': 'joy', 'score': 0.28243279457092285}, {'label': 'love', 'score': 0.0017966498853638768}, {'label': 'anger', 'score': 0.0034064981155097485}, {'label': 'fear', 'score': 0.011003700084984303}, {'label': 'surprise', 'score': 0.6972304582595825}]
# [{'label': 'sadness', 'score': 0.0013107372215017676}, {'label': 'joy', 'score': 0.0015903989551588893}, {'label': 'love', 'score': 0.001490283291786909}, {'label': 'anger', 'score': 0.0023534393403679132}, {'label': 'fear', 'score': 0.01881222054362297}, {'label': 'surprise', 'score': 0.9744429588317871}]
# [{'label': 'sadness', 'score': 0.004398751072585583}, {'label': 'joy', 'score': 0.02850200980901718}, {'label': 'love', 'score': 0.13007616996765137}, {'label': 'anger', 'score': 0.06433553248643875}, {'label': 'fear', 'score': 0.027247417718172073}, {'label': 'surprise', 'score': 0.7454401254653931}]
# [{'label': 'sadness', 'score': 0.001161801628768444}, {'label': 'joy', 'score': 0.002922795945778489}, {'label': 'love', 'score': 0.0009746668511070311}, {'label': 'anger', 'score': 0.0009871815564110875}, {'label': 'fear', 'score': 0.010183933191001415}, {'label': 'surprise', 'score': 0.9837696552276611}]
# [{'label': 'sadness', 'score': 0.000934199255425483}, {'label': 'joy', 'score': 0.0015783581184223294}, {'label': 'love', 'score': 0.007210950832813978}, {'label': 'anger', 'score': 0.9776726365089417}, {'label': 'fear', 'score': 0.009972421452403069}, {'label': 'surprise', 'score': 0.0026315280701965094}]
# [{'label': 'sadness', 'score': 0.0010062193032354116}, {'label': 'joy', 'score': 0.002792121609672904}, {'label': 'love', 'score': 0.0008390148868784308}, {'label': 'anger', 'score': 0.0007473216974176466}, {'label': 'fear', 'score': 0.004530414938926697}, {'label': 'surprise', 'score': 0.9900848865509033}]
# [{'label': 'sadness', 'score': 0.0017972261412069201}, {'label': 'joy', 'score': 0.008293548598885536}, {'label': 'love', 'score': 0.008401344530284405}, {'label': 'anger', 'score': 0.0011839000508189201}, {'label': 'fear', 'score': 0.0029144578147679567}, {'label': 'surprise', 'score': 0.9774094820022583}]
# [{'label': 'sadness', 'score': 0.0013021741760894656}, {'label': 'joy', 'score': 0.0031409987714141607}, {'label': 'love', 'score': 0.0015884505119174719}, {'label': 'anger', 'score': 0.0033235519658774137}, {'label': 'fear', 'score': 0.012088000774383545}, {'label': 'surprise', 'score': 0.9785568118095398}]
# [{'label': 'sadness', 'score': 0.0010400196770206094}, {'label': 'joy', 'score': 0.0018820598488673568}, {'label': 'love', 'score': 0.0012102900072932243}, {'label': 'anger', 'score': 0.0007289087516255677}, {'label': 'fear', 'score': 0.008055157028138638}, {'label': 'surprise', 'score': 0.9870835542678833}]
# [{'label': 'sadness', 'score': 0.003822547849267721}, {'label': 'joy', 'score': 0.0528838075697422}, {'label': 'love', 'score': 0.001540547702461481}, {'label': 'anger', 'score': 0.006425478029996157}, {'label': 'fear', 'score': 0.03591221943497658}, {'label': 'surprise', 'score': 0.8994153738021851}]
# [{'label': 'sadness', 'score': 0.001060262555256486}, {'label': 'joy', 'score': 0.002577413571998477}, {'label': 'love', 'score': 0.0011182889575138688}, {'label': 'anger', 'score': 0.0009079104638658464}, {'label': 'fear', 'score': 0.0040040877647697926}, {'label': 'surprise', 'score': 0.9903320670127869}]
# [{'label': 'sadness', 'score': 0.0052104126662015915}, {'label': 'joy', 'score': 0.4098321199417114}, {'label': 'love', 'score': 0.013473915867507458}, {'label': 'anger', 'score': 0.0017915917560458183}, {'label': 'fear', 'score': 0.012551861815154552}, {'label': 'surprise', 'score': 0.5571401119232178}]
# [{'label': 'sadness', 'score': 0.001252843183465302}, {'label': 'joy', 'score': 0.01386949047446251}, {'label': 'love', 'score': 0.0017629985231906176}, {'label': 'anger', 'score': 0.0010451329872012138}, {'label': 'fear', 'score': 0.006881057284772396}, {'label': 'surprise', 'score': 0.9751884341239929}]
# [{'label': 'sadness', 'score': 0.0012614181032404304}, {'label': 'joy', 'score': 0.0013110344298183918}, {'label': 'love', 'score': 0.0024157955776900053}, {'label': 'anger', 'score': 0.00133040442597121}, {'label': 'fear', 'score': 0.07234477996826172}, {'label': 'surprise', 'score': 0.9213365316390991}]
# [{'label': 'sadness', 'score': 0.00322393118403852}, {'label': 'joy', 'score': 0.05641259625554085}, {'label': 'love', 'score': 0.002293634694069624}, {'label': 'anger', 'score': 0.0016788392094895244}, {'label': 'fear', 'score': 0.00372681044973433}, {'label': 'surprise', 'score': 0.932664155960083}]
# [{'label': 'sadness', 'score': 0.002814958104863763}, {'label': 'joy', 'score': 0.12419746071100235}, {'label': 'love', 'score': 0.0015022446168586612}, {'label': 'anger', 'score': 0.002372490242123604}, {'label': 'fear', 'score': 0.012857910245656967}, {'label': 'surprise', 'score': 0.8562549352645874}]
# [{'label': 'sadness', 'score': 0.0009787424933165312}, {'label': 'joy', 'score': 0.002852576319128275}, {'label': 'love', 'score': 0.0009522949112579226}, {'label': 'anger', 'score': 0.001029256614856422}, {'label': 'fear', 'score': 0.005105630494654179}, {'label': 'surprise', 'score': 0.9890815019607544}]
# [{'label': 'sadness', 'score': 0.0009850256610661745}, {'label': 'joy', 'score': 0.0020653987303376198}, {'label': 'love', 'score': 0.0009466708870604634}, {'label': 'anger', 'score': 0.000724474957678467}, {'label': 'fear', 'score': 0.00481172651052475}, {'label': 'surprise', 'score': 0.9904666543006897}]
# [{'label': 'sadness', 'score': 0.0009315413190051913}, {'label': 'joy', 'score': 0.0026254765689373016}, {'label': 'love', 'score': 0.002301650121808052}, {'label': 'anger', 'score': 0.00045553225209005177}, {'label': 'fear', 'score': 0.0037173100281506777}, {'label': 'surprise', 'score': 0.989968478679657}]
# [{'label': 'sadness', 'score': 0.0010299748973920941}, {'label': 'joy', 'score': 0.0037294456269592047}, {'label': 'love', 'score': 0.005008882377296686}, {'label': 'anger', 'score': 0.0006067239446565509}, {'label': 'fear', 'score': 0.00544419139623642}, {'label': 'surprise', 'score': 0.9841808080673218}]
# [{'label': 'sadness', 'score': 0.0013325070030987263}, {'label': 'joy', 'score': 0.007483934983611107}, {'label': 'love', 'score': 0.0009912290843203664}, {'label': 'anger', 'score': 0.0006729974411427975}, {'label': 'fear', 'score': 0.004100472200661898}, {'label': 'surprise', 'score': 0.9854189157485962}]
# [{'label': 'sadness', 'score': 0.004049212206155062}, {'label': 'joy', 'score': 0.5696516633033752}, {'label': 'love', 'score': 0.010194207541644573}, {'label': 'anger', 'score': 0.012116649188101292}, {'label': 'fear', 'score': 0.022555677220225334}, {'label': 'surprise', 'score': 0.38143259286880493}]
# [{'label': 'sadness', 'score': 0.002921381266787648}, {'label': 'joy', 'score': 0.7888297438621521}, {'label': 'love', 'score': 0.009350611828267574}, {'label': 'anger', 'score': 0.002499312860891223}, {'label': 'fear', 'score': 0.0031148826237767935}, {'label': 'surprise', 'score': 0.1932840347290039}]
# [{'label': 'sadness', 'score': 0.0010455253068357706}, {'label': 'joy', 'score': 0.002097916789352894}, {'label': 'love', 'score': 0.0007625518483109772}, {'label': 'anger', 'score': 0.0008409348083660007}, {'label': 'fear', 'score': 0.009427121840417385}, {'label': 'surprise', 'score': 0.9858259558677673}]
# [{'label': 'sadness', 'score': 0.003585134632885456}, {'label': 'joy', 'score': 0.09060757607221603}, {'label': 'love', 'score': 0.0015822715358808637}, {'label': 'anger', 'score': 0.0041563548147678375}, {'label': 'fear', 'score': 0.010332250967621803}, {'label': 'surprise', 'score': 0.8897363543510437}]
# [{'label': 'sadness', 'score': 0.011298191733658314}, {'label': 'joy', 'score': 0.03451415151357651}, {'label': 'love', 'score': 0.02267313189804554}, {'label': 'anger', 'score': 0.007182255387306213}, {'label': 'fear', 'score': 0.06449104845523834}, {'label': 'surprise', 'score': 0.8598412871360779}]
# [{'label': 'sadness', 'score': 0.0028330557979643345}, {'label': 'joy', 'score': 0.12524442374706268}, {'label': 'love', 'score': 0.0015968162333592772}, {'label': 'anger', 'score': 0.0020872827153652906}, {'label': 'fear', 'score': 0.009231740608811378}, {'label': 'surprise', 'score': 0.8590067625045776}]
# [{'label': 'sadness', 'score': 0.0009886749321594834}, {'label': 'joy', 'score': 0.002022864529863}, {'label': 'love', 'score': 0.001081313588656485}, {'label': 'anger', 'score': 0.0006111221737228334}, {'label': 'fear', 'score': 0.003500332124531269}, {'label': 'surprise', 'score': 0.9917957186698914}]
# [{'label': 'sadness', 'score': 0.0022463782224804163}, {'label': 'joy', 'score': 0.022177476435899734}, {'label': 'love', 'score': 0.0024035221431404352}, {'label': 'anger', 'score': 0.006968246307224035}, {'label': 'fear', 'score': 0.04448771849274635}, {'label': 'surprise', 'score': 0.9217166900634766}]
# [{'label': 'sadness', 'score': 0.009126108139753342}, {'label': 'joy', 'score': 0.018119070678949356}, {'label': 'love', 'score': 0.23782823979854584}, {'label': 'anger', 'score': 0.04152996838092804}, {'label': 'fear', 'score': 0.03549326956272125}, {'label': 'surprise', 'score': 0.6579033732414246}]
# [{'label': 'sadness', 'score': 0.0009305077255703509}, {'label': 'joy', 'score': 0.9774379730224609}, {'label': 'love', 'score': 0.001655636471696198}, {'label': 'anger', 'score': 0.0007188486051745713}, {'label': 'fear', 'score': 0.0006408659392036498}, {'label': 'surprise', 'score': 0.01861623488366604}]
# [{'label': 'sadness', 'score': 0.004053595010191202}, {'label': 'joy', 'score': 0.006600613240152597}, {'label': 'love', 'score': 0.0018332927720621228}, {'label': 'anger', 'score': 0.01722560077905655}, {'label': 'fear', 'score': 0.03587400168180466}, {'label': 'surprise', 'score': 0.934412956237793}]
